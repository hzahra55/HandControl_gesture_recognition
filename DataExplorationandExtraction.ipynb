# %%
# Install required libraries
# !pip install kagglehub pandas plotly

import os
import pandas as pd
import plotly.express as px
import kagglehub
from google.colab import drive

# Step 1: Mount Google Drive (consistent with saving outputs later)
drive.mount('/content/drive')

# Step 2: Download the dataset using kagglehub
# Replace with the appropriate Kaggle dataset identifier
dataset_path = kagglehub.dataset_download("toxicmender/20bn-jester")
print("Path to dataset files:", dataset_path)

# Step 3: Verify the directory structure (consistent with manual verification from original code)
for root, dirs, files in os.walk(dataset_path):
    print(f"Directory: {root}")
    for file in files:
        print(f"  File: {file}")

# Step 4: Define dataset paths dynamically
root_directory = dataset_path  # Using the downloaded and extracted directory
labels_csv_path = os.path.join(root_directory, 'labels.csv')
train_csv_path = os.path.join(root_directory, 'Train.csv')
val_csv_path = os.path.join(root_directory, 'Validation.csv')
test_csv_path = os.path.join(root_directory, 'Test.csv')

print("Labels CSV Path:", labels_csv_path)
print("Train CSV Path:", train_csv_path)
print("Validation CSV Path:", val_csv_path)
print("Test CSV Path:", test_csv_path)

# Step 5: Load DataLoader with dynamic paths
# Ensure that lib/data_loader.py is uploaded to Colab or accessible
from lib.data_loader import DataLoader

data = DataLoader(labels_csv_path, train_csv_path, val_csv_path, test_csv_path)

# Step 6: Preview training data
print(data.train_df.head(10))

# Step 7: Summary of data
print('Training data: ', len(data.train_df))
print('Validation data: ', len(data.val_df))
print('Test data: ', len(data.test_df))

# Step 8: Plot class distribution
def plot_class_distribution(df):
    count = df['label'].value_counts()
    count_df = pd.DataFrame({'Hand Gesture': count.index, 'Number of Videos': count.values})
    fig = px.bar(count_df, x='Hand Gesture', y='Number of Videos', color='Hand Gesture')
    fig.show()

# Plot distributions (consistent with original code logic)
plot_class_distribution(data.train_df)
plot_class_distribution(data.val_df)

# Step 9: Filter and process chosen classes
chosen_classes = [
    'Swiping Left',
    'Swiping Right',
    'Swiping Down',
    'Swiping Up',
    'Sliding Two Fingers Down',
    'Sliding Two Fingers Up',
    'Thumb Down',
    'Thumb Up',
    'Stop Sign',
    'No gesture'
]

# Save chosen classes (consistent with original logic)
extracted_label_df = pd.DataFrame(chosen_classes)
extracted_label_path = os.path.join(root_directory, 'labels_extracted.csv')
extracted_label_df.to_csv(extracted_label_path, index=False, header=False)
print(f"Extracted labels saved to {extracted_label_path}")

# Reload DataLoader with extracted labels
data = DataLoader(extracted_label_path, train_csv_path, val_csv_path)

# Step 10: Extract specific subsets of data
def extract_data(original_df, labels, start, end):
    extracted_df = pd.DataFrame(columns=['video_id', 'label'])
    for label in labels:
        extracted_df = extracted_df.append(original_df[original_df['label'] == label].iloc[start:end+1])
    return extracted_df

# Extract train and validation subsets
extracted_train_df = extract_data(data.train_df, chosen_classes, 1, 800)
extracted_val_df = extract_data(data.val_df, chosen_classes, 1, 200)

# Save processed subsets to Google Drive (consistent with original saving workflow)
output_path = '/content/drive/My Drive/JesterDataset/processed/'
os.makedirs(output_path, exist_ok=True)
extracted_train_path = os.path.join(output_path, 'train_extracted.csv')
extracted_val_path = os.path.join(output_path, 'validation_extracted.csv')
extracted_train_df.to_csv(extracted_train_path, index=False)
extracted_val_df.to_csv(extracted_val_path, index=False)

print(f"Processed train data saved to {extracted_train_path}")
print(f"Processed validation data saved to {extracted_val_path}")

# Step 11: Reload DataLoader with processed data
data = DataLoader(extracted_label_path, extracted_train_path, extracted_val_path)

# Plot distributions for the extracted subsets (consistent with your original flow)
plot_class_distribution(data.train_df)
plot_class_distribution(data.val_df)
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.3.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2024.12.14)
# Mounted at /content/drive
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/toxicmender/20bn-jester?dataset_version_number=3...
# 100%|██████████| 11.9G/11.9G [02:23<00:00, 89.2MB/s]
# Extracting files...
# Streaming output truncated to the last 5000 lines.
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/107557
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/105058
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/38605
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/11339
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/48745
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/95866
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/89165
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/125903
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/37680
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/8987
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/146267
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/107049
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/88078
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/81928
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/12460
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/113248
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/106080
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/85031
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/39995
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/138304
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/71199
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/6629
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/82102
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/42865
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/102978
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/86914
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/60111
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/106829
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/76309
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/77000
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/40620
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/11316
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/79999
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/63158
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/119753
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/38891
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/19152
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/33024
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/63831
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/84453
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/48288
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/12661
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/118414
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/14231
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/37868
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/90900
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/101835
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/99323
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/104701
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/69817
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/143007
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/77545
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/13817
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/89837
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/2202
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/123316
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/128119
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/114788
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/8331
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/84823
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
# ...
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/2240
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/91332
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/121065
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/83473
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/31679
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/57909
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/142954
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/106112
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/4682
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/69344
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/91637
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/45308
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/92856
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/144058
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/135977
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/76552
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/67954
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/27685
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Directory: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation/42180
#   File: 00014.jpg
#   File: 00028.jpg
#   File: 00023.jpg
#   File: 00019.jpg
#   File: 00036.jpg
#   File: 00007.jpg
#   File: 00013.jpg
#   File: 00026.jpg
#   File: 00031.jpg
#   File: 00004.jpg
#   File: 00022.jpg
#   File: 00009.jpg
#   File: 00008.jpg
#   File: 00018.jpg
#   File: 00035.jpg
#   File: 00030.jpg
#   File: 00033.jpg
#   File: 00016.jpg
#   File: 00032.jpg
#   File: 00003.jpg
#   File: 00015.jpg
#   File: 00010.jpg
#   File: 00037.jpg
#   File: 00017.jpg
#   File: 00005.jpg
#   File: 00021.jpg
#   File: 00001.jpg
#   File: 00020.jpg
#   File: 00011.jpg
#   File: 00025.jpg
#   File: 00029.jpg
#   File: 00034.jpg
#   File: 00002.jpg
#   File: 00024.jpg
#   File: 00006.jpg
#   File: 00012.jpg
#   File: 00027.jpg
# Labels CSV Path: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/labels.csv
# Train CSV Path: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Train.csv
# Validation CSV Path: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation.csv
# Test CSV Path: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Test.csv
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a75ae993be93> in <cell line: 38>()
#      36 # Step 5: Load DataLoader with dynamic paths
#      37 # Ensure that lib/data_loader.py is uploaded to Colab or accessible
# ---> 38 from lib.data_loader import DataLoader
#      39
#      40 data = DataLoader(labels_csv_path, train_csv_path, val_csv_path, test_csv_path)
#
# ModuleNotFoundError: No module named 'lib.data_loader'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Mount Google Drive
from google.colab import drive
import sys
import os

drive.mount('/content/drive')

# Define the path to the lib folder
lib_path = '/content/drive/My Drive/lib'  # Update this path to your actual lib folder location
sys.path.append(lib_path)

# Import DataLoader
from data_loader import DataLoader

# Define dataset paths
root_directory = '/content/drive/My Drive/dataset'
labels_csv_path = os.path.join(root_directory, 'labels.csv')
train_csv_path = os.path.join(root_directory, 'Train.csv')
val_csv_path = os.path.join(root_directory, 'Validation.csv')
test_csv_path = os.path.join(root_directory, 'Test.csv')

# Initialize DataLoader with the correct paths
data = DataLoader(labels_csv_path, train_csv_path, val_csv_path, test_csv_path)



# Preview the training data
print("Training Data Sample:")
print(data.train_df.head(10))

# Summary of data
print(f"Training data: {len(data.train_df)}")
print(f"Validation data: {len(data.val_df)}")
print(f"Test data: {len(data.test_df)}")

# Function to plot class distribution
def plot_class_distribution(df):
    count = df['label'].value_counts()
    count_df = pd.DataFrame({'Hand Gesture': count.index, 'Number of Videos': count.values})
    fig = px.bar(count_df, x='Hand Gesture', y='Number of Videos', color='Hand Gesture')
    fig.show()

# Plot class distributions
print("Class Distribution in Training Data:")
plot_class_distribution(data.train_df)

print("Class Distribution in Validation Data:")
plot_class_distribution(data.val_df)

# Define chosen classes for filtering
chosen_classes = [
    'Swiping Left',
    'Swiping Right',
    'Swiping Down',
    'Swiping Up',
    'Sliding Two Fingers Down',
    'Sliding Two Fingers Up',
    'Thumb Down',
    'Thumb Up',
    'Stop Sign',
    'No gesture'
]

# Save chosen classes to a CSV
extracted_label_df = pd.DataFrame(chosen_classes)
extracted_label_path = os.path.join(root_directory, 'labels_extracted.csv')
extracted_label_df.to_csv(extracted_label_path, index=False, header=False)
print(f"Extracted labels saved to: {extracted_label_path}")

# Reload DataLoader with filtered labels
data = DataLoader(extracted_label_path, train_csv_path, val_csv_path)

# Function to extract specific subsets of data
def extract_data(original_df, labels, start, end):
    extracted_df = pd.DataFrame(columns=['video_id', 'label'])
    for label in labels:
        subset = original_df[original_df['label'] == label].iloc[start:end+1]
        extracted_df = pd.concat([extracted_df, subset], ignore_index=True)
    return extracted_df


# Extract subsets for training and validation
extracted_train_df = extract_data(data.train_df, chosen_classes, 1, 800)
extracted_val_df = extract_data(data.val_df, chosen_classes, 1, 200)

# Save extracted subsets
output_path = '/content/drive/My Drive/dataset/processed/'
os.makedirs(output_path, exist_ok=True)
extracted_train_path = os.path.join(output_path, 'train_extracted.csv')
extracted_val_path = os.path.join(output_path, 'validation_extracted.csv')
extracted_train_df.to_csv(extracted_train_path, index=False)
extracted_val_df.to_csv(extracted_val_path, index=False)

print(f"Extracted training data saved to: {extracted_train_path}")
print(f"Extracted validation data saved to: {extracted_val_path}")


# Reload DataLoader with processed data
data = DataLoader(extracted_label_path, extracted_train_path, extracted_val_path)

# Plot distributions for the extracted subsets
print("Class Distribution in Extracted Training Data:")
plot_class_distribution(data.train_df)

print("Class Distribution in Extracted Validation Data:")
plot_class_distribution(data.val_df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Training Data Sample:
#    video_id                        label
# 0         1           Doing other things
# 1         3     Pushing Two Fingers Away
# 2         6             Drumming Fingers
# 3        11     Sliding Two Fingers Down
# 4        14            Pushing Hand Away
# 5        17                 Shaking Hand
# 6        20           Doing other things
# 7        28       Pulling Two Fingers In
# 8        31                    Stop Sign
# 9        34  Zooming In With Two Fingers
# Training data: 50420
# Validation data: 7047
# Test data: 6981
# Class Distribution in Training Data:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="86e5b74f-0520-4ea3-bfab-9c95340e0255" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86e5b74f-0520-4ea3-bfab-9c95340e0255")) {                    Plotly.newPlot(                        "86e5b74f-0520-4ea3-bfab-9c95340e0255",                        [{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doing other things","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Doing other things","offsetgroup":"Doing other things","orientation":"v","showlegend":true,"textposition":"auto","x":["Doing other things"],"xaxis":"x","y":[4374],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pulling Two Fingers In","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Pulling Two Fingers In","offsetgroup":"Pulling Two Fingers In","orientation":"v","showlegend":true,"textposition":"auto","x":["Pulling Two Fingers In"],"xaxis":"x","y":[1859],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zooming Out With Two Fingers","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Zooming Out With Two Fingers","offsetgroup":"Zooming Out With Two Fingers","orientation":"v","showlegend":true,"textposition":"auto","x":["Zooming Out With Two Fingers"],"xaxis":"x","y":[1847],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No gesture","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"No gesture","offsetgroup":"No gesture","orientation":"v","showlegend":true,"textposition":"auto","x":["No gesture"],"xaxis":"x","y":[1844],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pushing Two Fingers Away","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Pushing Two Fingers Away","offsetgroup":"Pushing Two Fingers Away","orientation":"v","showlegend":true,"textposition":"auto","x":["Pushing Two Fingers Away"],"xaxis":"x","y":[1843],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thumb Up","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Thumb Up","offsetgroup":"Thumb Up","orientation":"v","showlegend":true,"textposition":"auto","x":["Thumb Up"],"xaxis":"x","y":[1841],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sliding Two Fingers Down","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sliding Two Fingers Down","offsetgroup":"Sliding Two Fingers Down","orientation":"v","showlegend":true,"textposition":"auto","x":["Sliding Two Fingers Down"],"xaxis":"x","y":[1832],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zooming Out With Full Hand","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Zooming Out With Full Hand","offsetgroup":"Zooming Out With Full Hand","orientation":"v","showlegend":true,"textposition":"auto","x":["Zooming Out With Full Hand"],"xaxis":"x","y":[1832],"yaxis":"y","type":"bar"},{"alignmentg ...
# Class Distribution in Validation Data:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="80235c8f-a631-41c3-92e8-e15ded52c52c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80235c8f-a631-41c3-92e8-e15ded52c52c")) {                    Plotly.newPlot(                        "80235c8f-a631-41c3-92e8-e15ded52c52c",                        [{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doing other things","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Doing other things","offsetgroup":"Doing other things","orientation":"v","showlegend":true,"textposition":"auto","x":["Doing other things"],"xaxis":"x","y":[713],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zooming In With Full Hand","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Zooming In With Full Hand","offsetgroup":"Zooming In With Full Hand","orientation":"v","showlegend":true,"textposition":"auto","x":["Zooming In With Full Hand"],"xaxis":"x","y":[262],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zooming Out With Two Fingers","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Zooming Out With Two Fingers","offsetgroup":"Zooming Out With Two Fingers","orientation":"v","showlegend":true,"textposition":"auto","x":["Zooming Out With Two Fingers"],"xaxis":"x","y":[261],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zooming Out With Full Hand","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Zooming Out With Full Hand","offsetgroup":"Zooming Out With Full Hand","orientation":"v","showlegend":true,"textposition":"auto","x":["Zooming Out With Full Hand"],"xaxis":"x","y":[260],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stop Sign","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Stop Sign","offsetgroup":"Stop Sign","orientation":"v","showlegend":true,"textposition":"auto","x":["Stop Sign"],"xaxis":"x","y":[259],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Drumming Fingers","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Drumming Fingers","offsetgroup":"Drumming Fingers","orientation":"v","showlegend":true,"textposition":"auto","x":["Drumming Fingers"],"xaxis":"x","y":[257],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zooming In With Two Fingers","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Zooming In With Two Fingers","offsetgroup":"Zooming In With Two Fingers","orientation":"v","showlegend":true,"textposition":"auto","x":["Zooming In With Two Fingers"],"xaxis":"x","y":[257],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No gesture","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"No gesture","offsetgroup":"No gesture","orientation":"v","showlegend":true,"textposition":"auto","x":["No gesture"],"xaxis":"x","y":[256],"yaxis":"y","type":"bar"},{"alignmentgroup":"True" ...
# Extracted labels saved to: /content/drive/My Drive/dataset/labels_extracted.csv
# Extracted training data saved to: /content/drive/My Drive/dataset/processed/train_extracted.csv
# Extracted validation data saved to: /content/drive/My Drive/dataset/processed/validation_extracted.csv
# Class Distribution in Extracted Training Data:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="49b98539-77e7-4dce-b11b-468fcead43e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49b98539-77e7-4dce-b11b-468fcead43e1")) {                    Plotly.newPlot(                        "49b98539-77e7-4dce-b11b-468fcead43e1",                        [{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Left","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Swiping Left","offsetgroup":"Swiping Left","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Left"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Right","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Swiping Right","offsetgroup":"Swiping Right","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Right"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Down","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Swiping Down","offsetgroup":"Swiping Down","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Down"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Up","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Swiping Up","offsetgroup":"Swiping Up","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Up"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sliding Two Fingers Down","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Sliding Two Fingers Down","offsetgroup":"Sliding Two Fingers Down","orientation":"v","showlegend":true,"textposition":"auto","x":["Sliding Two Fingers Down"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sliding Two Fingers Up","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Sliding Two Fingers Up","offsetgroup":"Sliding Two Fingers Up","orientation":"v","showlegend":true,"textposition":"auto","x":["Sliding Two Fingers Up"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thumb Down","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Thumb Down","offsetgroup":"Thumb Down","orientation":"v","showlegend":true,"textposition":"auto","x":["Thumb Down"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thumb Up","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Thumb Up","offsetgroup":"Thumb Up","orientation":"v","showlegend":true,"textposition":"auto","x":["Thumb Up"],"xaxis":"x","y":[800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stop Sign","marker":{"color":"#FF97FF","pattern":{"shape":""}},"n ...
# Class Distribution in Extracted Validation Data:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f9931a0-81c4-4593-8e96-5883a79e79af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f9931a0-81c4-4593-8e96-5883a79e79af")) {                    Plotly.newPlot(                        "9f9931a0-81c4-4593-8e96-5883a79e79af",                        [{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Left","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Swiping Left","offsetgroup":"Swiping Left","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Left"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Right","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Swiping Right","offsetgroup":"Swiping Right","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Right"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Down","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Swiping Down","offsetgroup":"Swiping Down","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Down"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Swiping Up","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Swiping Up","offsetgroup":"Swiping Up","orientation":"v","showlegend":true,"textposition":"auto","x":["Swiping Up"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sliding Two Fingers Down","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Sliding Two Fingers Down","offsetgroup":"Sliding Two Fingers Down","orientation":"v","showlegend":true,"textposition":"auto","x":["Sliding Two Fingers Down"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sliding Two Fingers Up","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Sliding Two Fingers Up","offsetgroup":"Sliding Two Fingers Up","orientation":"v","showlegend":true,"textposition":"auto","x":["Sliding Two Fingers Up"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thumb Down","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Thumb Down","offsetgroup":"Thumb Down","orientation":"v","showlegend":true,"textposition":"auto","x":["Thumb Down"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thumb Up","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Thumb Up","offsetgroup":"Thumb Up","orientation":"v","showlegend":true,"textposition":"auto","x":["Thumb Up"],"xaxis":"x","y":[200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Hand Gesture=%{x}\u003cbr\u003eNumber of Videos=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stop Sign","marker":{"color":"#FF97FF","pattern":{"shape":""}},"n ...

# %%
import os

# Define the dataset path
dataset_path = '/root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3'

# Check for CSV files only
print("CSV files in the dataset directory:")
for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.endswith('.csv'):
            print(f"File: {os.path.join(root, file)}")
# Out:
# CSV files in the dataset directory:
# File: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Validation.csv
# File: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Train.csv
# File: /root/.cache/kagglehub/datasets/toxicmender/20bn-jester/versions/3/Test.csv

# %%
import pandas as pd

# %%
# Install and import required libraries
# !pip install plotly
import plotly.express as px
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.2)
